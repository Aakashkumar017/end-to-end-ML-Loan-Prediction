# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loan=pd.read_csv(r"C:\Users\Amit kumar\Downloads\loan_data.csv")   #load the data
# loan = pd.read_csv(r"C:\Users\Amit kumar\Downloads\loan_data_2000_rows.csv")
loan = pd.read_csv(
    r"C:\Users\Amit kumar\Downloads\loan_data_2000_with_nulls_and_3plus.csv"
)

# %%
loan = loan.replace({pd.NA: np.nan})

# %%
loan.head(10) # show top 5 row
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP100000    Male     Yes          1      Graduate            No
# 1  LP100001  Female     Yes         3+      Graduate            No
# 2  LP100002  Female      No          2  Not Graduate           Yes
# 3  LP100003  Female     Yes          0      Graduate            No
# 4  LP100004    Male     Yes          0      Graduate            No
# 5  LP100005    Male      No          0  Not Graduate            No
# 6  LP100006    Male     Yes          0      Graduate            No
# 7  LP100007  Female      No          0      Graduate            No
# 8  LP100008  Female     Yes          2      Graduate            No
# 9  LP100009  Female     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           2363.0             9843.0       179.0             180.0
# 1          16383.0             4177.0       341.0               NaN
# ...

# %%
loan.isnull().sum()
# Out:
# Loan_ID                0
# Gender                86
# Married              102
# Dependents           109
# Education             44
# Self_Employed         83
# ApplicantIncome        0
# CoapplicantIncome      0
# LoanAmount             0
# Loan_Amount_Term     111
# Credit_History       153
# Property_Area         97
# Loan_Status            0
# dtype: int64

# %%
loan["Loan_Status"] = loan["Loan_Status"].fillna(
    loan["Loan_Status"].mode()[0]
)

# %%
loan.tail(5) # show last 5 row
# Out:
#        Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1995  LP101995  Female     Yes          2      Graduate            No
# 1996  LP101996  Female     Yes          1      Graduate            No
# 1997  LP101997    Male     Yes          2      Graduate            No
# 1998  LP101998    Male     Yes          1  Not Graduate            No
# 1999  LP101999    Male     Yes          0      Graduate            No
#
#       ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1995          24076.0            11982.0       152.0             300.0
# 1996          19561.0             5350.0       417.0             360.0
# 1997          13833.0              533.0       541.0             360.0
# 1998          13438.0             8593.0       607.0             180.0
# 1999          13048.0             3663.0       317.0             360.0
#
#       Credit_History Property_Area Loan_Status
# 1995             1.0         Rural           Y
# ...

# %%
loan.describe() # show staatical information
# Out:
#        ApplicantIncome  CoapplicantIncome   LoanAmount  Loan_Amount_Term  \
# count      2000.000000        2000.000000  2000.000000       1889.000000
# mean      13458.491500        7384.708500   371.562000        314.166226
# std        6758.508332        4301.359657   188.851732         68.692818
# min        1505.000000           0.000000    50.000000        180.000000
# 25%        7722.500000        3745.250000   209.000000        300.000000
# 50%       13462.000000        7218.000000   361.500000        360.000000
# 75%       19446.250000       10990.000000   537.000000        360.000000
# max       24965.000000       14990.000000   699.000000        360.000000
#
#        Credit_History
# count     1847.000000
# mean         0.752572
# std          0.431635
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
loan.info() # check information abount and columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            2000 non-null   object
#  1   Gender             1914 non-null   object
#  2   Married            1898 non-null   object
#  3   Dependents         1891 non-null   object
#  4   Education          1956 non-null   object
#  5   Self_Employed      1917 non-null   object
#  6   ApplicantIncome    2000 non-null   float64
#  7   CoapplicantIncome  2000 non-null   float64
#  8   LoanAmount         2000 non-null   float64
#  9   Loan_Amount_Term   1889 non-null   float64
#  10  Credit_History     1847 non-null   float64
#  11  Property_Area      1903 non-null   object
#  12  Loan_Status        2000 non-null   object
# dtypes: float64(5), object(8)
# memory usage: 203.3+ KB

# %%
loan.isnull().sum() # check the null value each row
# Out:
# Loan_ID                0
# Gender                86
# Married              102
# Dependents           109
# Education             44
# Self_Employed         83
# ApplicantIncome        0
# CoapplicantIncome      0
# LoanAmount             0
# Loan_Amount_Term     111
# Credit_History       153
# Property_Area         97
# Loan_Status            0
# dtype: int64

# %%
# replace 3+ into 3
loan["Dependents"].replace("3+", "3", inplace=True)
# Out:
# C:\Users\Amit kumar\AppData\Local\Temp\ipykernel_6324\3685636078.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   loan["Dependents"].replace("3+", "3", inplace=True)

# %%
loan["Dependents"]=loan["Dependents"].astype("Float64")

# %%
float_values_row=loan.select_dtypes(include='float64')  # show how many null value in float columns
float_values_row
# Out:
#       Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0            1.0           2363.0             9843.0       179.0
# 1            3.0          16383.0             4177.0       341.0
# 2            2.0          13645.0             7211.0       325.0
# 3            0.0           4555.0             7873.0       425.0
# 4            0.0          23017.0             3841.0       104.0
# ...          ...              ...                ...         ...
# 1995         2.0          24076.0            11982.0       152.0
# 1996         1.0          19561.0             5350.0       417.0
# 1997         2.0          13833.0              533.0       541.0
# 1998         1.0          13438.0             8593.0       607.0
# 1999         0.0          13048.0             3663.0       317.0
#
#       Loan_Amount_Term  Credit_History
# 0                180.0             1.0
# 1                  NaN             0.0
# 2                360.0             1.0
# ...

# %%
col = [
    "Dependents",
    "ApplicantIncome",
    "CoapplicantIncome",
    "LoanAmount",
    "Loan_Amount_Term",
    "Credit_History"
]
col
# Out:
# ['Dependents',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %%
from sklearn.impute import SimpleImputer

# %%
# use sklearn impute function to  fill null value
float_filling=SimpleImputer(strategy='mean')
loan[col]=float_filling.fit_transform(loan[col])

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            2000 non-null   object
#  1   Gender             1914 non-null   object
#  2   Married            1898 non-null   object
#  3   Dependents         2000 non-null   float64
#  4   Education          1956 non-null   object
#  5   Self_Employed      1917 non-null   object
#  6   ApplicantIncome    2000 non-null   float64
#  7   CoapplicantIncome  2000 non-null   float64
#  8   LoanAmount         2000 non-null   float64
#  9   Loan_Amount_Term   2000 non-null   float64
#  10  Credit_History     2000 non-null   float64
#  11  Property_Area      1903 non-null   object
#  12  Loan_Status        2000 non-null   object
# dtypes: float64(6), object(7)
# memory usage: 203.3+ KB

# %%
object_values_row=loan.select_dtypes(include='object')  # show how many null value in float columns
object_values_row
# Out:
#        Loan_ID  Gender Married     Education Self_Employed Property_Area  \
# 0     LP100000    Male     Yes      Graduate            No     Semiurban
# 1     LP100001  Female     Yes      Graduate            No     Semiurban
# 2     LP100002  Female      No  Not Graduate           Yes     Semiurban
# 3     LP100003  Female     Yes      Graduate            No     Semiurban
# 4     LP100004    Male     Yes      Graduate            No         Urban
# ...        ...     ...     ...           ...           ...           ...
# 1995  LP101995  Female     Yes      Graduate            No         Rural
# 1996  LP101996  Female     Yes      Graduate            No         Urban
# 1997  LP101997    Male     Yes      Graduate            No     Semiurban
# 1998  LP101998    Male     Yes  Not Graduate            No         Urban
# 1999  LP101999    Male     Yes      Graduate            No     Semiurban
#
#      Loan_Status
# 0              N
# 1              N
# 2              Y
# 3              Y
# ...

# %%
obj=["Gender","Married","Education","Self_Employed","Property_Area"]

# %%
loan[obj] = loan[obj].replace({pd.NA: np.nan})

# %%
loan[obj].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Gender         1914 non-null   object
#  1   Married        1898 non-null   object
#  2   Education      1956 non-null   object
#  3   Self_Employed  1917 non-null   object
#  4   Property_Area  1903 non-null   object
# dtypes: object(5)
# memory usage: 78.3+ KB

# %%
obj=["Gender","Married","Education","Self_Employed","Property_Area"]

# %%
for col in obj:
    print(f"\nValue counts for {col}:\n")
    print(loan[col].value_counts())
# Out:
# Value counts for Gender:
#
# Gender
# Female    970
# Male      944
# Name: count, dtype: int64
#
# Value counts for Married:
#
# Married
# Yes    1297
# No      601
# Name: count, dtype: int64
#
# Value counts for Education:
#
# Education
# Graduate        1526
# Not Graduate     430
# Name: count, dtype: int64
#
# Value counts for Self_Employed:
#
# Self_Employed
# No     1622
# Yes     295
# Name: count, dtype: int64
#
# Value counts for Property_Area:
#
# Property_Area
# Semiurban    670
# Urban        625
# Rural        608
# Name: count, dtype: int64

# %%
# use sklearn impute function to  fill null value
obj_filling=SimpleImputer(strategy='most_frequent')
loan[obj]=obj_filling.fit_transform(loan[obj])

# %%
loan["Loan_Status"] = loan["Loan_Status"].map({"N": 0, "Y": 1})

# %%
loan.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
loan.info()
loan.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            2000 non-null   object
#  1   Gender             2000 non-null   object
#  2   Married            2000 non-null   object
#  3   Dependents         2000 non-null   float64
#  4   Education          2000 non-null   object
#  5   Self_Employed      2000 non-null   object
#  6   ApplicantIncome    2000 non-null   float64
#  7   CoapplicantIncome  2000 non-null   float64
#  8   LoanAmount         2000 non-null   float64
#  9   Loan_Amount_Term   2000 non-null   float64
#  10  Credit_History     2000 non-null   float64
#  11  Property_Area      2000 non-null   object
#  12  Loan_Status        2000 non-null   int64
# dtypes: float64(6), int64(1), object(6)
# memory usage: 203.3+ KB
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# ...

# %%
loan["Dependents"].value_counts()
# Out:
# Dependents
# 0.000000    924
# 1.000000    401
# 3.000000    286
# 2.000000    280
# 0.961925    109
# Name: count, dtype: int64

# %%
loan
# Out:
#        Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0     LP100000    Male     Yes         1.0      Graduate            No
# 1     LP100001  Female     Yes         3.0      Graduate            No
# 2     LP100002  Female      No         2.0  Not Graduate           Yes
# 3     LP100003  Female     Yes         0.0      Graduate            No
# 4     LP100004    Male     Yes         0.0      Graduate            No
# ...        ...     ...     ...         ...           ...           ...
# 1995  LP101995  Female     Yes         2.0      Graduate            No
# 1996  LP101996  Female     Yes         1.0      Graduate            No
# 1997  LP101997    Male     Yes         2.0      Graduate            No
# 1998  LP101998    Male     Yes         1.0  Not Graduate            No
# 1999  LP101999    Male     Yes         0.0      Graduate            No
#
#       ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
loan.drop("Loan_ID", axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

binary_cols = ["Gender", "Married", "Self_Employed"]

le = LabelEncoder()
for col in binary_cols:
    loan[col] = le.fit_transform(loan[col])

# %%
loan = pd.get_dummies(
    loan,
    columns=["Education", "Property_Area"],
    drop_first=True
)

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   2000 non-null   int32
#  1   Married                  2000 non-null   int32
#  2   Dependents               2000 non-null   float64
#  3   Self_Employed            2000 non-null   int32
#  4   ApplicantIncome          2000 non-null   float64
#  5   CoapplicantIncome        2000 non-null   float64
#  6   LoanAmount               2000 non-null   float64
#  7   Loan_Amount_Term         2000 non-null   float64
#  8   Credit_History           2000 non-null   float64
#  9   Loan_Status              2000 non-null   int64
#  10  Education_Not Graduate   2000 non-null   bool
#  11  Property_Area_Semiurban  2000 non-null   bool
#  12  Property_Area_Urban      2000 non-null   bool
# dtypes: bool(3), float64(6), int32(3), int64(1)
# ...

# %%
loan
# Out:
#       Gender  Married  Dependents  Self_Employed  ApplicantIncome  \
# 0          1        1         1.0              0           2363.0
# 1          0        1         3.0              0          16383.0
# 2          0        0         2.0              1          13645.0
# 3          0        1         0.0              0           4555.0
# 4          1        1         0.0              0          23017.0
# ...      ...      ...         ...            ...              ...
# 1995       0        1         2.0              0          24076.0
# 1996       0        1         1.0              0          19561.0
# 1997       1        1         2.0              0          13833.0
# 1998       1        1         1.0              0          13438.0
# 1999       1        1         0.0              0          13048.0
#
#       CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                9843.0       179.0        180.000000        1.000000
# ...

# %%
loan.describe()
# Out:
#            Gender     Married   Dependents  Self_Employed  ApplicantIncome  \
# count  2000.00000  2000.00000  2000.000000    2000.000000      2000.000000
# mean      0.47200     0.69950     0.961925       0.147500     13458.491500
# std       0.49934     0.45859     1.083151       0.354692      6758.508332
# min       0.00000     0.00000     0.000000       0.000000      1505.000000
# 25%       0.00000     0.00000     0.000000       0.000000      7722.500000
# 50%       0.00000     1.00000     0.961925       0.000000     13462.000000
# 75%       1.00000     1.00000     2.000000       0.000000     19446.250000
# max       1.00000     1.00000     3.000000       1.000000     24965.000000
#
#        CoapplicantIncome   LoanAmount  Loan_Amount_Term  Credit_History  \
# count        2000.000000  2000.000000       2000.000000     2000.000000
# mean         7384.708500   371.562000        314.166226        0.752572
# std          4301.359657   188.851732         66.758402        0.414787
# ...

# %%
loan.isnull().sum()
# Out:
# Gender                     0
# Married                    0
# Dependents                 0
# Self_Employed              0
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                 0
# Loan_Amount_Term           0
# Credit_History             0
# Loan_Status                0
# Education_Not Graduate     0
# Property_Area_Semiurban    0
# Property_Area_Urban        0
# dtype: int64

# %%
# we already use decribe function and look which colums has outlier
num_cols = ["ApplicantIncome", "CoapplicantIncome", "LoanAmount"]

for col in num_cols:
    plt.figure()
    sns.boxplot(x=loan[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
for col in ["ApplicantIncome", "CoapplicantIncome", "LoanAmount"]:
    Q1 = loan[col].quantile(0.25)
    Q3 = loan[col].quantile(0.75)
    IQR = Q3 - Q1
    upper = Q3 + 1.5 * IQR
    
    print(col, "max:", loan[col].max(), "upper limit:", upper)
# Out:
# ApplicantIncome max: 24965.0 upper limit: 37031.875
# CoapplicantIncome max: 14990.0 upper limit: 21857.125
# LoanAmount max: 699.0 upper limit: 1029.0

# %%
#DEFINE X AND Y FOR FEATURE 
x= loan.drop("Loan_Status", axis=1)
y = loan["Loan_Status"]

# %%
x.shape
# Out:
# (2000, 12)

# %%
x.isnull().sum()
# Out:
# Gender                     0
# Married                    0
# Dependents                 0
# Self_Employed              0
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                 0
# Loan_Amount_Term           0
# Credit_History             0
# Education_Not Graduate     0
# Property_Area_Semiurban    0
# Property_Area_Urban        0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=40,stratify=y)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("model", LogisticRegression(
        max_iter=1000,
        class_weight="balanced"
    ))
])

# Train the full pipeline
pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_pred = pipeline.predict(x_test)

# %%
y_prob = pipeline.predict_proba(x_test)[:, 1]

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score

print("Accuracy:", accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

print("ROC–AUC:", roc_auc_score(y_test, y_prob))
# Out:
# Accuracy: 0.925
# [[308  29]
#  [ 16 247]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93       337
#            1       0.89      0.94      0.92       263
#
#     accuracy                           0.93       600
#    macro avg       0.92      0.93      0.92       600
# weighted avg       0.93      0.93      0.93       600
#
# ROC–AUC: 0.9709018289311866

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

fpr, tpr, _ = roc_curve(y_test, y_prob)

plt.plot(fpr, tpr, label="Logistic Regression (Pipeline)")
plt.plot([0, 1], [0, 1], "--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
import joblib
joblib.dump(pipeline, "loan_approval_pipeline.pkl")
# Out:
# ['loan_approval_pipeline.pkl']

# %%
# save dataset 
loan.to_csv("../data/dataset.csv", index=False)
